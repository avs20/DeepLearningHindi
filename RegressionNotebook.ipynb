# %% [markdown]
# <a href="https://colab.research.google.com/github/avs20/DeepLearningHindi/blob/main/RegressionNotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nnfs
# Out:
# Requirement already satisfied: nnfs in /usr/local/lib/python3.7/dist-packages (0.5.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from nnfs) (1.19.5)

# %%
import numpy as np
import nnfs
from nnfs.datasets import sine_data

nnfs.init()


# Dense layer
class Layer_Dense:

    # Layer initialization
    def __init__(self, n_inputs, n_neurons,
                 weight_regularizer_l1=0, weight_regularizer_l2=0,
                 bias_regularizer_l1=0, bias_regularizer_l2=0):
        # Initialize weights and biases
        self.weights = 0.01 * np.random.randn(n_inputs, n_neurons)
        self.biases = np.zeros((1, n_neurons))
        # Set regularization strength
        self.weight_regularizer_l1 = weight_regularizer_l1
        self.weight_regularizer_l2 = weight_regularizer_l2
        self.bias_regularizer_l1 = bias_regularizer_l1
        self.bias_regularizer_l2 = bias_regularizer_l2

    # Forward pass
    def forward(self, inputs):
        # Remember input values
        self.inputs = inputs
        # Calculate output values from inputs, weights and biases
        self.output = np.dot(inputs, self.weights) + self.biases

    # Backward pass
    def backward(self, dvalues):
        # Gradients on parameters
        self.dweights = np.dot(self.inputs.T, dvalues)
        self.dbiases = np.sum(dvalues, axis=0, keepdims=True)


        # Gradients on regularization
        # L1 on weights
        if self.weight_regularizer_l1 > 0:
            dL1 = np.ones_like(self.weights)
            dL1[self.weights < 0] = -1
            self.dweights += self.weight_regularizer_l1 * dL1
        # L2 on weights
        if self.weight_regularizer_l2 > 0:
            self.dweights += 2 * self.weight_regularizer_l2 * \
                             self.weights
        # L1 on biases
        if self.bias_regularizer_l1 > 0:
            dL1 = np.ones_like(self.biases)
            dL1[self.biases < 0] = -1
            self.dbiases += self.bias_regularizer_l1 * dL1
        # L2 on biases
        if self.bias_regularizer_l2 > 0:
            self.dbiases += 2 * self.bias_regularizer_l2 * \
                            self.biases

        # Gradient on values
        self.dinputs = np.dot(dvalues, self.weights.T)


# Dropout
class Layer_Dropout:

    # Init
    def __init__(self, rate):
        # Store rate, we invert it as for example for dropout
        # of 0.1 we need success rate of 0.9
        self.rate = 1 - rate

    # Forward pass
    def forward(self, inputs):
        # Save input values
        self.inputs = inputs
        # Generate and save scaled mask
        self.binary_mask = np.random.binomial(1, self.rate,
                           size=inputs.shape) / self.rate
        # Apply mask to output values
        self.output = inputs * self.binary_mask

    # Backward pass
    def backward(self, dvalues):
        # Gradient on values
        self.dinputs = dvalues * self.binary_mask

# ReLU activation
class Activation_ReLU:

    # Forward pass
    def forward(self, inputs):
        # Remember input values
        self.inputs = inputs
        # Calculate output values from inputs
        self.output = np.maximum(0, inputs)

    # Backward pass
    def backward(self, dvalues):
        # Since we need to modify original variable,
        # let's make a copy of values first
        self.dinputs = dvalues.copy()

        # Zero gradient where input values were negative
        self.dinputs[self.inputs <= 0] = 0



# Sigmoid activation
class Activation_Sigmoid:

    # Forward pass
    def forward(self, inputs):
        # Save input and calculate/save output
        # of the sigmoid function
        self.inputs = inputs
        self.output = 1 / (1 + np.exp(-inputs))

    # Backward pass
    def backward(self, dvalues):
        # Derivative - calculates from output of the sigmoid function
        self.dinputs = dvalues * (1 - self.output) * self.output


# Linear activation
class Activation_Linear:

    # Forward pass
    def forward(self, inputs):
        # Just remember values
        self.inputs = inputs
        self.output = inputs

    # Backward pass
    def backward(self, dvalues):
        # derivative is 1, 1 * dvalues = dvalues - the chain rule
        self.dinputs = dvalues.copy()


# SGD optimizer
class Optimizer_SGD:

    # Initialize optimizer - set settings,
    # learning rate of 1. is default for this optimizer
    def __init__(self, learning_rate=1., decay=0., momentum=0.):
        self.learning_rate = learning_rate
        self.current_learning_rate = learning_rate
        self.decay = decay
        self.iterations = 0
        self.momentum = momentum

    # Call once before any parameter updates
    def pre_update_params(self):
        if self.decay:
            self.current_learning_rate = self.learning_rate * \
                (1. / (1. + self.decay * self.iterations))

    # Update parameters
    def update_params(self, layer):

        # If we use momentum
        if self.momentum:

            # If layer does not contain momentum arrays, create them
            # filled with zeros
            if not hasattr(layer, 'weight_momentums'):
                layer.weight_momentums = np.zeros_like(layer.weights)
                # If there is no momentum array for weights
                # The array doesn't exist for biases yet either.
                layer.bias_momentums = np.zeros_like(layer.biases)

            # Build weight updates with momentum - take previous
            # updates multiplied by retain factor and update with
            # current gradients
            weight_updates = \
                self.momentum * layer.weight_momentums - \
                self.current_learning_rate * layer.dweights
            layer.weight_momentums = weight_updates

            # Build bias updates
            bias_updates = \
                self.momentum * layer.bias_momentums - \
                self.current_learning_rate * layer.dbiases
            layer.bias_momentums = bias_updates

        # Vanilla SGD updates (as before momentum update)
        else:
            weight_updates = -self.current_learning_rate * \
                             layer.dweights
            bias_updates = -self.current_learning_rate * \
                           layer.dbiases

        # Update weights and biases using either
        # vanilla or momentum updates
        layer.weights += weight_updates
        layer.biases += bias_updates
    # Call once after any parameter updates
    def post_update_params(self):
        self.iterations += 1



# Adam optimizer
class Optimizer_Adam:

    # Initialize optimizer - set settings
    def __init__(self, learning_rate=0.001, decay=0., epsilon=1e-7,
                 beta_1=0.9, beta_2=0.999):
        self.learning_rate = learning_rate
        self.current_learning_rate = learning_rate
        self.decay = decay
        self.iterations = 0
        self.epsilon = epsilon
        self.beta_1 = beta_1
        self.beta_2 = beta_2

    # Call once before any parameter updates
    def pre_update_params(self):
        if self.decay:
            self.current_learning_rate = self.learning_rate * \
                (1. / (1. + self.decay * self.iterations))

    # Update parameters
    def update_params(self, layer):

        # If layer does not contain cache arrays,
        # create them filled with zeros
        if not hasattr(layer, 'weight_cache'):
            layer.weight_momentums = np.zeros_like(layer.weights)
            layer.weight_cache = np.zeros_like(layer.weights)
            layer.bias_momentums = np.zeros_like(layer.biases)
            layer.bias_cache = np.zeros_like(layer.biases)

        # Update momentum  with current gradients
        layer.weight_momentums = self.beta_1 * \
                                 layer.weight_momentums + \
                                 (1 - self.beta_1) * layer.dweights
        layer.bias_momentums = self.beta_1 * \
                               layer.bias_momentums + \
                               (1 - self.beta_1) * layer.dbiases
        # Get corrected momentum
        # self.iteration is 0 at first pass
        # and we need to start with 1 here
        weight_momentums_corrected = layer.weight_momentums / \
            (1 - self.beta_1 ** (self.iterations + 1))
        bias_momentums_corrected = layer.bias_momentums / \
            (1 - self.beta_1 ** (self.iterations + 1))
        # Update cache with squared current gradients
        layer.weight_cache = self.beta_2 * layer.weight_cache + \
            (1 - self.beta_2) * layer.dweights**2
        layer.bias_cache = self.beta_2 * layer.bias_cache + \
            (1 - self.beta_2) * layer.dbiases**2
        # Get corrected cache
        weight_cache_corrected = layer.weight_cache / \
            (1 - self.beta_2 ** (self.iterations + 1))
        bias_cache_corrected = layer.bias_cache / \
            (1 - self.beta_2 ** (self.iterations + 1))

        # Vanilla SGD parameter update + normalization
        # with square rooted cache
        layer.weights += -self.current_learning_rate * \
                         weight_momentums_corrected / \
                         (np.sqrt(weight_cache_corrected) +
                             self.epsilon)
        layer.biases += -self.current_learning_rate * \
                         bias_momentums_corrected / \
                         (np.sqrt(bias_cache_corrected) +
                             self.epsilon)

    # Call once after any parameter updates
    def post_update_params(self):
        self.iterations += 1


# Common loss class
class Loss:

    # Regularization loss calculation
    def regularization_loss(self, layer):

        # 0 by default
        regularization_loss = 0

        # L1 regularization - weights
        # calculate only when factor greater than 0
        if layer.weight_regularizer_l1 > 0:
            regularization_loss += layer.weight_regularizer_l1 * \
                                   np.sum(np.abs(layer.weights))

        # L2 regularization - weights
        if layer.weight_regularizer_l2 > 0:
            regularization_loss += layer.weight_regularizer_l2 * \
                                   np.sum(layer.weights * \
                                          layer.weights)


        # L1 regularization - biases
        # calculate only when factor greater than 0
        if layer.bias_regularizer_l1 > 0:
            regularization_loss += layer.bias_regularizer_l1 * \
                                   np.sum(np.abs(layer.biases))

        # L2 regularization - biases
        if layer.bias_regularizer_l2 > 0:
            regularization_loss += layer.bias_regularizer_l2 * \
                                   np.sum(layer.biases * \
                                          layer.biases)

        return regularization_loss

    # Calculates the data and regularization losses
    # given model output and ground truth values
    def calculate(self, output, y):

        # Calculate sample losses
        sample_losses = self.forward(output, y)

        # Calculate mean loss
        data_loss = np.mean(sample_losses)

        # Return loss
        return data_loss


# Mean Squared Error loss
class Loss_MeanSquaredError(Loss):  # L2 loss

    # Forward pass
    def forward(self, y_pred, y_true):

        # Calculate loss
        sample_losses = np.mean((y_true - y_pred)**2, axis=-1)

        # Return losses
        return sample_losses

    # Backward pass
    def backward(self, dvalues, y_true):

        # Number of samples
        samples = len(dvalues)
        # Number of outputs in every sample
        # We'll use the first sample to count them
        outputs = len(dvalues[0])

        # Gradient on values
        self.dinputs = -2 * (y_true - dvalues) / outputs
        # Normalize gradient
        self.dinputs = self.dinputs / samples


# Mean Absolute Error loss
class Loss_MeanAbsoluteError(Loss):  # L1 loss

    # Forward pass
    def forward(self, y_pred, y_true):

        # Calculate loss
        sample_losses = np.mean(np.abs(y_true - y_pred), axis=-1)

        # Return losses
        return sample_losses


    # Backward pass
    def backward(self, dvalues, y_true):

        # Number of samples
        samples = len(dvalues)
        # Number of outputs in every sample
        # We'll use the first sample to count them
        outputs = len(dvalues[0])

        # Calculate gradient
        self.dinputs = np.sign(y_true - dvalues) / outputs
        # Normalize gradient
        self.dinputs = self.dinputs / samples


# Create dataset
X, y = sine_data()

# %%
import matplotlib.pyplot as plt 

# %matplotlib inline 
plt.plot(X,y)
print(X.shape)
# Out:
# (1000, 1)

# %%
# Create Dense layer with 1 input feature and 64 output values
dense1 = Layer_Dense(1, 64)

# Create ReLU activation (to be used with Dense layer):
activation1 = Activation_ReLU()

# Create second Dense layer with 64 input features (as we take output
# of previous layer here) and 64 output values
dense2 = Layer_Dense(64, 1)

# Create ReLU activation (to be used with Dense layer):
activation2 = Activation_Linear()

# # Create third Dense layer with 64 input features (as we take output
# # of previous layer here) and 1 output value
# dense3 = Layer_Dense(64, 1)

# Create Linear activation:
# activation3 = Activation_Linear()

# Create loss function
loss_function = Loss_MeanSquaredError()

# Create optimizer
optimizer = Optimizer_Adam()


# Accuracy precision for accuracy calculation
# There are no really accuracy factor for regression problem,
# but we can simulate/approximate it. We'll calculate it by checking
# how many values have a difference to their ground truth equivalent
# less than given precision
# We'll calculate this precision as a fraction of standard deviation
# of all the ground truth values
accuracy_precision = np.std(y) / 250

# Train in loop
for epoch in range(10001):

    # Perform a forward pass of our training data through this layer
    dense1.forward(X)

    # Perform a forward pass through activation function
    # takes the output of first dense layer here
    activation1.forward(dense1.output)

    # Perform a forward pass through second Dense layer
    # takes outputs of activation function
    # of first layer as inputs
    dense2.forward(activation1.output)

    # Perform a forward pass through activation function
    # takes the output of second dense layer here
    activation2.forward(dense2.output)

    # Perform a forward pass through third Dense layer
    # takes outputs of activation function of second layer as inputs
    # dense3.forward(activation2.output)

    # Perform a forward pass through activation function
    # takes the output of third dense layer here
    # activation3.forward(dense3.output)

    # Calculate the data loss
    data_loss = loss_function.calculate(activation2.output, y)

    # Calculate regularization penalty
    regularization_loss = \
        loss_function.regularization_loss(dense1) + \
        loss_function.regularization_loss(dense2) 
        # loss_function.regularization_loss(dense3)

    # Calculate overall loss
    loss = data_loss + regularization_loss

    # Calculate accuracy from output of activation2 and targets
    # To calculate it we're taking absolute difference between
    # predictions and ground truth values and compare if differences
    # are lower than given precision value
    predictions = activation2.output
    accuracy = np.mean(np.absolute(predictions - y) <
                       accuracy_precision)

    if not epoch % 100:
        print(f'epoch: {epoch}, ' +
              f'acc: {accuracy:.3f}, ' +
              f'loss: {loss:.3f} (' +
              f'data_loss: {data_loss:.3f}, ' +
              f'reg_loss: {regularization_loss:.3f}), ' +
              f'lr: {optimizer.current_learning_rate}')

    # Backward pass
    loss_function.backward(activation2.output, y)
    # activation3.backward(loss_function.dinputs)
    # dense3.backward(activation3.dinputs)
    activation2.backward(loss_function.dinputs)
    dense2.backward(activation2.dinputs)
    activation1.backward(dense2.dinputs)
    dense1.backward(activation1.dinputs)

    # Update weights and biases
    optimizer.pre_update_params()
    optimizer.update_params(dense1)
    optimizer.update_params(dense2)
    # optimizer.update_params(dense3)
    optimizer.post_update_params()


import matplotlib.pyplot as plt

X_test, y_test = sine_data()

dense1.forward(X_test)
activation1.forward(dense1.output)
dense2.forward(activation1.output)
activation2.forward(dense2.output)
# dense3.forward(activation2.output)
# activation3.forward(dense3.output)

plt.plot(X_test, y_test)
plt.plot(X_test, activation2.output)
plt.show()
# Out:
# epoch: 0, acc: 0.002, loss: 0.500 (data_loss: 0.500, reg_loss: 0.000), lr: 0.001
# epoch: 100, acc: 0.003, loss: 0.343 (data_loss: 0.343, reg_loss: 0.000), lr: 0.001
# epoch: 200, acc: 0.003, loss: 0.166 (data_loss: 0.166, reg_loss: 0.000), lr: 0.001
# epoch: 300, acc: 0.003, loss: 0.149 (data_loss: 0.149, reg_loss: 0.000), lr: 0.001
# epoch: 400, acc: 0.003, loss: 0.149 (data_loss: 0.149, reg_loss: 0.000), lr: 0.001
# epoch: 500, acc: 0.004, loss: 0.148 (data_loss: 0.148, reg_loss: 0.000), lr: 0.001
# epoch: 600, acc: 0.003, loss: 0.147 (data_loss: 0.147, reg_loss: 0.000), lr: 0.001
# epoch: 700, acc: 0.003, loss: 0.147 (data_loss: 0.147, reg_loss: 0.000), lr: 0.001
# epoch: 800, acc: 0.004, loss: 0.147 (data_loss: 0.147, reg_loss: 0.000), lr: 0.001
# epoch: 900, acc: 0.004, loss: 0.146 (data_loss: 0.146, reg_loss: 0.000), lr: 0.001
# epoch: 1000, acc: 0.004, loss: 0.146 (data_loss: 0.146, reg_loss: 0.000), lr: 0.001
# epoch: 1100, acc: 0.003, loss: 0.146 (data_loss: 0.146, reg_loss: 0.000), lr: 0.001
# epoch: 1200, acc: 0.003, loss: 0.146 (data_loss: 0.146, reg_loss: 0.000), lr: 0.001
# epoch: 1300, acc: 0.004, loss: 0.146 (data_loss: 0.146, reg_loss: 0.000), lr: 0.001
# epoch: 1400, acc: 0.003, loss: 0.146 (data_loss: 0.146, reg_loss: 0.000), lr: 0.001
# epoch: 1500, acc: 0.004, loss: 0.146 (data_loss: 0.146, reg_loss: 0.000), lr: 0.001
# epoch: 1600, acc: 0.003, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 1700, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 1800, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 1900, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 2000, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 2100, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 2200, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 2300, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 2400, acc: 0.003, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 2500, acc: 0.003, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 2600, acc: 0.003, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 2700, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 2800, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 2900, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 3000, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 3100, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 3200, acc: 0.003, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 3300, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 3400, acc: 0.003, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 3500, acc: 0.003, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 3600, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 3700, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 3800, acc: 0.003, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 3900, acc: 0.003, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 4000, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 4100, acc: 0.003, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 4200, acc: 0.003, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 4300, acc: 0.003, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 4400, acc: 0.003, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 4500, acc: 0.003, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 4600, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 4700, acc: 0.003, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 4800, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 4900, acc: 0.003, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 5000, acc: 0.003, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 5100, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 5200, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 5300, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 5400, acc: 0.003, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 5500, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 5600, acc: 0.003, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 5700, acc: 0.003, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 5800, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 5900, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 6000, acc: 0.003, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 6100, acc: 0.003, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 6200, acc: 0.003, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 6300, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 6400, acc: 0.003, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 6500, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 6600, acc: 0.003, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 6700, acc: 0.003, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 6800, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 6900, acc: 0.003, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 7000, acc: 0.003, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 7100, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 7200, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 7300, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 7400, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 7500, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 7600, acc: 0.003, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 7700, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 7800, acc: 0.003, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 7900, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 8000, acc: 0.003, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 8100, acc: 0.003, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 8200, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 8300, acc: 0.003, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 8400, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 8500, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 8600, acc: 0.003, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 8700, acc: 0.003, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 8800, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 8900, acc: 0.003, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 9000, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 9100, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 9200, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 9300, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 9400, acc: 0.003, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 9500, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 9600, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 9700, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 9800, acc: 0.003, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 9900, acc: 0.003, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001
# epoch: 10000, acc: 0.004, loss: 0.145 (data_loss: 0.145, reg_loss: 0.000), lr: 0.001

# %%
# Create Dense layer with 1 input feature and 64 output values
dense1 = Layer_Dense(1, 64)

# Create ReLU activation (to be used with Dense layer):
activation1 = Activation_ReLU()

# Create second Dense layer with 64 input features (as we take output
# of previous layer here) and 64 output values
dense2 = Layer_Dense(64, 64)

# Create ReLU activation (to be used with Dense layer):
activation2 = Activation_ReLU()

# # Create third Dense layer with 64 input features (as we take output
# # of previous layer here) and 1 output value
dense3 = Layer_Dense(64, 1)

# Create Linear activation:
activation3 = Activation_Linear()

# Create loss function
loss_function = Loss_MeanSquaredError()

# Create optimizer
optimizer = Optimizer_Adam()


# Accuracy precision for accuracy calculation
# There are no really accuracy factor for regression problem,
# but we can simulate/approximate it. We'll calculate it by checking
# how many values have a difference to their ground truth equivalent
# less than given precision
# We'll calculate this precision as a fraction of standard deviation
# of all the ground truth values
accuracy_precision = np.std(y) / 250

# Train in loop
for epoch in range(10001):

    # Perform a forward pass of our training data through this layer
    dense1.forward(X)

    # Perform a forward pass through activation function
    # takes the output of first dense layer here
    activation1.forward(dense1.output)

    # Perform a forward pass through second Dense layer
    # takes outputs of activation function
    # of first layer as inputs
    dense2.forward(activation1.output)

    # Perform a forward pass through activation function
    # takes the output of second dense layer here
    activation2.forward(dense2.output)

    # Perform a forward pass through third Dense layer
    # takes outputs of activation function of second layer as inputs
    dense3.forward(activation2.output)

    # Perform a forward pass through activation function
    # takes the output of third dense layer here
    activation3.forward(dense3.output)

    # Calculate the data loss
    data_loss = loss_function.calculate(activation3.output, y)

    # Calculate regularization penalty
    regularization_loss = \
        loss_function.regularization_loss(dense1) + \
        loss_function.regularization_loss(dense2) + \
        loss_function.regularization_loss(dense3)

    # Calculate overall loss
    loss = data_loss + regularization_loss

    # Calculate accuracy from output of activation2 and targets
    # To calculate it we're taking absolute difference between
    # predictions and ground truth values and compare if differences
    # are lower than given precision value
    predictions = activation3.output
    accuracy = np.mean(np.absolute(predictions - y) <
                       accuracy_precision)

    if not epoch % 100:
        print(f'epoch: {epoch}, ' +
              f'acc: {accuracy:.3f}, ' +
              f'loss: {loss:.3f} (' +
              f'data_loss: {data_loss:.3f}, ' +
              f'reg_loss: {regularization_loss:.3f}), ' +
              f'lr: {optimizer.current_learning_rate}')

    # Backward pass
    loss_function.backward(activation3.output, y)
    activation3.backward(loss_function.dinputs)
    dense3.backward(activation3.dinputs)
    activation2.backward(dense3.dinputs)
    dense2.backward(activation2.dinputs)
    activation1.backward(dense2.dinputs)
    dense1.backward(activation1.dinputs)

    # Update weights and biases
    optimizer.pre_update_params()
    optimizer.update_params(dense1)
    optimizer.update_params(dense2)
    optimizer.update_params(dense3)
    optimizer.post_update_params()


import matplotlib.pyplot as plt

X_test, y_test = sine_data()

dense1.forward(X_test)
activation1.forward(dense1.output)
dense2.forward(activation1.output)
activation2.forward(dense2.output)
dense3.forward(activation2.output)
activation3.forward(dense3.output)

plt.plot(X_test, y_test)
plt.plot(X_test, activation3.output)
plt.show()
# Out:
# epoch: 0, acc: 0.002, loss: 0.500 (data_loss: 0.500, reg_loss: 0.000), lr: 0.001
# epoch: 100, acc: 0.004, loss: 0.128 (data_loss: 0.128, reg_loss: 0.000), lr: 0.001
# epoch: 200, acc: 0.005, loss: 0.105 (data_loss: 0.105, reg_loss: 0.000), lr: 0.001
# epoch: 300, acc: 0.005, loss: 0.087 (data_loss: 0.087, reg_loss: 0.000), lr: 0.001
# epoch: 400, acc: 0.009, loss: 0.060 (data_loss: 0.060, reg_loss: 0.000), lr: 0.001
# epoch: 500, acc: 0.114, loss: 0.033 (data_loss: 0.033, reg_loss: 0.000), lr: 0.001
# epoch: 600, acc: 0.021, loss: 0.014 (data_loss: 0.014, reg_loss: 0.000), lr: 0.001
# epoch: 700, acc: 0.118, loss: 0.005 (data_loss: 0.005, reg_loss: 0.000), lr: 0.001
# epoch: 800, acc: 0.465, loss: 0.002 (data_loss: 0.002, reg_loss: 0.000), lr: 0.001
# epoch: 900, acc: 0.526, loss: 0.001 (data_loss: 0.001, reg_loss: 0.000), lr: 0.001
# epoch: 1000, acc: 0.591, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 1100, acc: 0.627, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 1200, acc: 0.546, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 1300, acc: 0.667, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 1400, acc: 0.675, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 1500, acc: 0.047, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 1600, acc: 0.696, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 1700, acc: 0.235, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 1800, acc: 0.715, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 1900, acc: 0.703, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 2000, acc: 0.734, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 2100, acc: 0.743, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 2200, acc: 0.749, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 2300, acc: 0.758, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 2400, acc: 0.767, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 2500, acc: 0.773, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 2600, acc: 0.367, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 2700, acc: 0.788, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 2800, acc: 0.793, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 2900, acc: 0.359, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 3000, acc: 0.810, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 3100, acc: 0.818, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 3200, acc: 0.274, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 3300, acc: 0.829, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 3400, acc: 0.830, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 3500, acc: 0.833, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 3600, acc: 0.645, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 3700, acc: 0.838, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 3800, acc: 0.841, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 3900, acc: 0.826, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 4000, acc: 0.845, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 4100, acc: 0.842, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 4200, acc: 0.852, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 4300, acc: 0.852, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 4400, acc: 0.856, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 4500, acc: 0.198, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 4600, acc: 0.860, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 4700, acc: 0.101, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 4800, acc: 0.866, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 4900, acc: 0.869, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 5000, acc: 0.873, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 5100, acc: 0.877, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 5200, acc: 0.878, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 5300, acc: 0.880, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 5400, acc: 0.880, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 5500, acc: 0.887, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 5600, acc: 0.879, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 5700, acc: 0.893, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 5800, acc: 0.885, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 5900, acc: 0.896, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 6000, acc: 0.899, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 6100, acc: 0.899, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 6200, acc: 0.899, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 6300, acc: 0.902, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 6400, acc: 0.904, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 6500, acc: 0.905, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 6600, acc: 0.887, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 6700, acc: 0.908, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 6800, acc: 0.519, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 6900, acc: 0.912, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 7000, acc: 0.903, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 7100, acc: 0.916, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 7200, acc: 0.917, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 7300, acc: 0.912, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 7400, acc: 0.919, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 7500, acc: 0.920, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 7600, acc: 0.922, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 7700, acc: 0.162, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 7800, acc: 0.925, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 7900, acc: 0.155, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 8000, acc: 0.927, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 8100, acc: 0.538, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 8200, acc: 0.929, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 8300, acc: 0.929, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 8400, acc: 0.930, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 8500, acc: 0.934, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 8600, acc: 0.934, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 8700, acc: 0.932, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 8800, acc: 0.935, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 8900, acc: 0.925, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 9000, acc: 0.933, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 9100, acc: 0.939, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 9200, acc: 0.893, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 9300, acc: 0.939, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 9400, acc: 0.942, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 9500, acc: 0.943, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 9600, acc: 0.948, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 9700, acc: 0.945, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 9800, acc: 0.945, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 9900, acc: 0.947, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001
# epoch: 10000, acc: 0.950, loss: 0.000 (data_loss: 0.000, reg_loss: 0.000), lr: 0.001

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

figure(figsize=(14, 10), dpi=80)

X_test, y_test = sine_data()

dense1.forward(X_test)
activation1.forward(dense1.output)
dense2.forward(activation1.output)
activation2.forward(dense2.output)
dense3.forward(activation2.output)
activation3.forward(dense3.output)


plt.plot(X_test, y_test, c = 'b')
plt.plot(X_test, activation3.output, c='r')
plt.show()
